# %% [markdown]
# EAE3709 APLICACIONES DE  MACHINE LEARNING EN ECONOMÍA <br>
# 1ER SEMESTRE 2025 <br>
# INSTITUTO DE ECONOMÍA <br>
# PONTIFICIA UNIVERSIDAD CATÓLICA DE CHILE
#
#
# # **TAREA 1**
#
#
# ---
#
#
# Profesor:
# - Joaquín Pérez Lapillo
#
# Ayudantes:
#
# - Luis García B.
# - Sebastián Hernández B.
# - Oscar Herrera G.

# %% [markdown]
# **Complete sus datos:**
#
# - Nombre y apellido:
#   - `Fernando Parra`
#   - `Cristian Díaz`
# - Usuario de GitHub (opcional):  `cristiandiazh'

# %% [markdown]
# ## Instrucciones
#
# - Descargue el notebook y cárguelo en su Drive.
# - Todas las preguntas deben ser contestadas en su notebook.
# - Para que una pregunta esté correcta el código debe correr.
# - Si es necesario, realice comentarios breves en su código explicando lo que está realizando o sus resultados.
# - Una vez culminada su tarea, suba su notebook al buzón de tareas de Canvas.
# - La fecha y hora límite de esta tarea es el _**viernes 4 de abril a las 18:00 hrs**_.

# %% [markdown]
# ### Distribución de puntaje
#
#
# | Pregunta                        | Puntaje |
# |--------------------------------|---------|
# | Pregunta 1.0                   |    1    |
# | Pregunta 1.1                   |    3    |
# | Pregunta 1.2                   |    3    |
# | Pregunta 1.3                   |    2    |
# | Pregunta 1.4                   |    2    |
# | Pregunta 1.5                   |    5    |
# | Pregunta 1.6                   |    2    |
# | Pregunta 1.7                   |    5    |
# | Pregunta 1.8                   |   7    |
# | Pregunta 1.9                   |   5    |
# | Pregunta 1.10                  |   5    |
# | Pregunta 1.11                  |   6    |
# | Pregunta 1.12                  |    2    |
# | Pregunta 1.13                  |    5    |
# | Pregunta 1.14                  |   10    |
# | Pregunta 1.15                  |    5    |
# | Pregunta 1.16                  |    5    |
# | Pregunta 2.0                   |    2    |
# | Pregunta 2.1                   |    5    |
# | Pregunta 2.2                   |    5    |
# | Pregunta 2.3                   |    5    |
# | Pregunta 2.4                   |    3    |
# | Pregunta 2.5                   |    3    |
# | Pregunta 2.6                   |    2    |
# | Pregunta 2.7                   |    2    |
#
# Total: 100 pts.

# %% [markdown]
# ### Sobre el Bonus
#
# - La entrega, por defecto, es a través de Canvas. Sin embargo, puede escoger voluntariamente entregar la tarea en su GitHub personal.
#
# - Si usted realiza la entrega en GitHub antes de la **fecha y hora indicada**, entonces tendrá una bonificación de 0.3 en su nota final de tarea. Es decir, si usted obtuvo una nota de 6.5, pero entregó en su GitHub, entonces su calificación en esta tarea será de 6.8.
#
# - Si **además** de realizar la entrega a través de GitHub, usted logra crear `branches` (ramas) y realizar un `merge` entre ramas, entonces se le bonificará con 0.5 en su nota de tarea. Es decir, si usted obtuvo una nota de 6.5, pero entregó en su GitHub e hizo el trabajo de ramas, entonces su calificación en esta tarea será de 7.0.
#
#   - Se valora capacidad autodidacta.
#   - Sólo serán considerados los archivos contenidos en su rama principal a la fecha y hora indicada.

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %% [markdown]
# Para esta tarea se utilizará como principal fuente de información un dataset con una serie de características económicas, demográficas y de desarrollo humano de distintos países a la fecha de 2007 (corte transversal). El dataset está disponible en el siguiente [Github](https://raw.githubusercontent.com/lfgarcia-1/EAE3709-1-2025/refs/heads/main/economic_dataset.csv).<br>
#
# Descripción del dataset:
#
# Variables:
#
# *   date: Fecha en la que se actualizó la data.
# *   Population, Area (sq. mi.) Pop. Density (per sq. mi.), Coastline (coast/area ratio), Net migration, Infant mortality (per 1000 births), GDP ($ per capita, Literacy (%), Phones (per 1000), Arable (%), Crops (%), Other (%), Climate, Birthrate, Deathrate, Agriculture, Industry, Service: Características del país.
# *   source: fuente de los datos.
# *   Region: Región (grupo de países).
# *   Country: País.

# %% [markdown]
# |
# ## Pregunta 1.0
#
# Importe las librerías que usará en su tarea.

# %%
# Librerías manejo de datos
import pandas as pd
import numpy as np
# Librerías para graficar
import matplotlib.pyplot as plt
import seaborn as sns

# Librería que filtra warnings innecesarios
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Pregunta 1.1
#
# Importe el dataset como un DataFrame (df) directamente desde Github (es decir, no descargue el archivo manualmente). A lo largo de la tarea este df se denominará como `df`.

# %%
url = "https://raw.githubusercontent.com/lfgarcia-1/EAE3709-1-2025/refs/heads/main/economic_dataset.csv"
df = pd.read_csv(url)
pd.set_option('display.max_columns', None) #para que el df muestre todas las columnas

# %% [markdown]
# ### Pregunta 1.2
#
# Utilice las funciones de Pandas `head()`, `tail()`, `info()` y la propiedad (o atributo) `.dtypes` para describir el `df`. Explique brevemente para qué sirve cada función.

# %%
df.head()
#Head nos muestra las primeras 5 filas y todas las columnas del df, con eso podemos tener una idea de como son los datos
# Out:
#          date        source          Country  \
# 0  2007-01-01  US Goverment     Afghanistan
# 1  2007-01-01  US Goverment         Albania
# 2  2007-01-01  US Goverment         Algeria
# 3  2007-01-01  US Goverment  American Samoa
# 4  2007-01-01  US Goverment         Andorra
#
#                                 Region  Population  Area (sq. mi.)  \
# 0        ASIA (EX. NEAR EAST)             31056997          647500
# 1  EASTERN EUROPE                          3581655           28748
# 2  NORTHERN AFRICA                        32930091         2381740
# 3  OCEANIA                                   57794             199
# 4  WESTERN EUROPE                            71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# 2                        13.8                          0.04          -0.39
# 3                       290.4                         58.29         -20.71
# 4                       152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                              163.07               700.0          36.0
# 1                               21.52              4500.0          86.5
# 2                               31.00              6000.0          70.0
# 3                                9.27              8000.0          97.0
# 4                                4.05             19000.0         100.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                3.2       12.13       0.22      87.65      1.0      46.60
# 1               71.2       21.09       4.42      74.49      3.0      15.11
# 2               78.1        3.22       0.25      96.53      1.0      17.14
# 3              259.5       10.00      15.00      75.00      2.0      22.46
# 4              497.2        2.22       0.00      97.78      3.0       8.71
#
#    Deathrate  Agriculture  Industry  Service
# 0      20.34        0.380     0.240    0.380
# 1       5.22        0.232     0.188    0.579
# 2       4.61        0.101     0.600    0.298
# 3       3.27          NaN       NaN      NaN
# 4       6.25          NaN       NaN      NaN

# %%
df.tail()# similar a head, pero nos muestra los ultimos 5 datos
# Out:
#            date        source          Country  \
# 222  2007-01-01  US Goverment       West Bank
# 223  2007-01-01  US Goverment  Western Sahara
# 224  2007-01-01  US Goverment           Yemen
# 225  2007-01-01  US Goverment          Zambia
# 226  2007-01-01  US Goverment        Zimbabwe
#
#                                   Region  Population  Area (sq. mi.)  \
# 222  NEAR EAST                               2460492            5860
# 223  NORTHERN AFRICA                          273008          266000
# 224  NEAR EAST                              21456188          527970
# 225  SUB-SAHARAN AFRICA                     11502010          752614
# 226  SUB-SAHARAN AFRICA                     12236805          390580
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 222                       419.9                          0.00           2.98
# 223                         1.0                          0.42            NaN
# 224                        40.6                          0.36           0.00
# 225                        15.3                          0.00           0.00
# 226                        31.3                          0.00           0.00
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 222                               19.62               800.0           NaN
# 223                                 NaN                 NaN           NaN
# 224                               61.50               800.0          50.2
# 225                               88.29               800.0          80.6
# 226                               67.69              1900.0          90.7
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 222              145.2       16.90      18.97      64.13      3.0      31.67
# 223                NaN        0.02       0.00      99.98      1.0        NaN
# 224               37.2        2.78       0.24      96.98      1.0      42.89
# 225                8.2        7.08       0.03      92.90      2.0      41.00
# 226               26.8        8.32       0.34      91.34      2.0      28.01
#
#      Deathrate  Agriculture  Industry  Service
# 222       3.92        0.090     0.280    0.630
# 223        NaN          NaN       NaN    0.400
# 224       8.30        0.135     0.472    0.393
# 225      19.93        0.220     0.290    0.489
# 226      21.84        0.179     0.243    0.579

# %%
df.info() # nos informa sobre el tipo de dato de cada columna, y el numero de datos de cada columna que tiene datos. Además nos da
          # un pequeño resumen de la cantidad de columnas que hay por cada tipo de dato
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                227 non-null    object
#  1   source                              227 non-null    object
#  2   Country                             227 non-null    object
#  3   Region                              227 non-null    object
#  4   Population                          227 non-null    int64
#  5   Area (sq. mi.)                      227 non-null    int64
#  6   Pop. Density (per sq. mi.)          227 non-null    float64
#  7   Coastline (coast/area ratio)        227 non-null    float64
#  8   Net migration                       224 non-null    float64
#  9   Infant mortality (per 1000 births)  224 non-null    float64
#  10  GDP ($ per capita)                  226 non-null    float64
#  11  Literacy (%)                        209 non-null    float64
#  12  Phones (per 1000)                   223 non-null    float64
#  13  Arable (%)                          225 non-null    float64
#  14  Crops (%)                           225 non-null    float64
#  15  Other (%)                           225 non-null    float64
#  16  Climate                             205 non-null    float64
#  17  Birthrate                           224 non-null    float64
#  18  Deathrate                           223 non-null    float64
#  19  Agriculture                         212 non-null    float64
#  20  Industry                            211 non-null    float64
#  21  Service                             212 non-null    float64
# dtypes: float64(16), int64(2), object(4)
# memory usage: 39.1+ KB

# %%
df.dtypes # similar a info() pero solo se enfoca en el tipo de dato de cada columna
# Out:
# date                                   object
# source                                 object
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %% [markdown]
# ### Pregunta 1.3
#
# La variable `source` es innecesaria debido que contiene el mismo valor para todas las observaciones. Elimine esta variable de su `df`.

# %%
df = df.drop("source", axis=1)

# %% [markdown]
# ### Pregunta 1.4
#
# Transforme el tipo de la variable `date` a `datetime` _datatype_.

# %%
df["date"]=pd.to_datetime(df["date"])

# %% [markdown]
# ### Pregunta 1.5
#
# Para determinar si las variables son "útiles" y sus valores son "correctos" es necesario comprender cada uno de los atributos del dataset.
# Investigue y explique brevemente la relación **teórica** entre el `GDP (% per capita)` y cada una de las variables denominadas como "Características del país" en la introducción.
#
# Ejemplo: Existe una variable denominada `Coastline (coast/area ratio)`. Coastline es una medida de la cantidad de costa (acceso a mar) del país normalizada al área total del país para no beneficiar a países más grandes pero con la misma proporción de costa. A mayor "Costline" aumenta la capacidad portuaria per capita del país, más puertos facilita el comercio y podría aumentar el GDP per cápita.

# %% [markdown]
# ---
#
#
# Población: a mayor población es más facil alcanzar economias de escalas y mercados más profundos que aumenten el GDP, y por lo tanto el GDP per capita.
#
# Area: Una mayor area ocupable permite a los paises tener más opciones para especializarce y acceder más a recursos valiosos, lo que aumenta las probabilidades de aumentar el valor producido, y con ello el GDP per capita.
#
# Densidad poblacional: Una alta densidad poblacional tiene un efecto ambiguo en el pib per capita, puesto que por un lado está correlacionado con paises pequeños y ricos, que tienen altas productividades y tecnologías. Por otro lado, también puede significar sobrepoblación y falta de recursos, por lo que la literatura no es muy clara al respecto todavía.
#
# Coastline (coast/area ratio): Países con acceso al mar tienden a beneficiarse del comercio marítimo, impulsando el GDP per cápita.
#
# Net migration: Una migración neta positiva puede aumentar el PIB per cápita si los migrantes aportan capital humano calificado.
#
# Infant mortality (per 1000 births): Alta mortalidad infantil suele asociarse con menor PIB per cápita debido a deficiencias en salud y desarrollo.
#
# Literacy (%): Mayores tasas de alfabetización suelen estar vinculadas a mayores ingresos per cápita, debido a que por un lado se tienen los recuros para gastar en educación, y porque luego esa educación aumenta el valor agregado y el GDP per capita.
#
# Phones (per 1000): Un mayor acceso a telecomunicaciones permite mayor flujo de información, lo que favorece la productividad y el GDP per capita. Además, está relacionado inversamente, pues mayor pib per capita permite que la gente tenga dinero suficiente para acceder a los teléfonos.
#
# Arable (%): Una mayor proporción de tierra cultivable puede beneficiar el PIB per cápita en cuanto aumente su valor agregado con la tecnologia.
#
# Crops (%): Depender excesivamente de cultivos puede indicar una economía menos diversificada y con menor PIB per cápita.
#
# Other (%): Depende del uso que se les da, pero generalmente se hace referencia a urbanización lo que está relacionado positivamente con el GDP per capita
#
# Climate: Climas extremos pueden afectar el desarrollo económico, mientras que climas templados favorecen la productividad.
#
# Birthrate: Tasas de natalidad muy altas pueden reducir el PIB per cápita si no hay inversión suficiente en capital humano.
#
# Deathrate: Altas tasas de mortalidad pueden indicar problemas de desarrollo, relacionado principalmente con bajo GDP per capita
#
# Agriculture: Economías con una alta proporción en agricultura suelen tener menor PIB per cápita.
#
# Industry: Un sector industrial fuerte suele estar correlacionado con mayores
# ingresos per cápita.
#
# Service: Países con un sector de servicios desarrollado tienden a tener mayor PIB per cápita, reflejando economías avanzadas.
#
#
# ---

# %% [markdown]
# ### Pregunta 1.6
#
# Calcule estadísticas descriptivas para cada variable numérica.

# %%
df.describe()
# Out:
#                       date    Population  Area (sq. mi.)  \
# count                  227  2.270000e+02    2.270000e+02
# mean   2007-01-01 00:00:00  2.874028e+07    5.982270e+05
# min    2007-01-01 00:00:00  7.026000e+03    2.000000e+00
# 25%    2007-01-01 00:00:00  4.376240e+05    4.647500e+03
# 50%    2007-01-01 00:00:00  4.786994e+06    8.660000e+04
# 75%    2007-01-01 00:00:00  1.749777e+07    4.418110e+05
# max    2007-01-01 00:00:00  1.313974e+09    1.707520e+07
# std                    NaN  1.178913e+08    1.790282e+06
#
#        Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# count                  227.000000                    227.000000
# mean                   379.047137                     21.165330
# min                      0.000000                      0.000000
# 25%                     29.150000                      0.100000
# 50%                     78.800000                      0.730000
# 75%                    190.150000                     10.345000
# max                  16271.500000                    870.660000
# std                   1660.185825                     72.286863
#
#        Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# count     224.000000                          224.000000          226.000000
# mean        0.038125                           35.506964         9689.823009
# min       -20.990000                            2.290000          500.000000
# 25%        -0.927500                            8.150000         1900.000000
# 50%         0.000000                           21.000000         5550.000000
# 75%         0.997500                           55.705000        15700.000000
# max        23.060000                          191.190000        55100.000000
# std         4.889269                           35.389899        10049.138513
#
#        Literacy (%)  Phones (per 1000)  Arable (%)   Crops (%)   Other (%)  \
# count    209.000000         223.000000  225.000000  225.000000  225.000000
# mean      82.838278         236.061435   13.797111    4.564222   81.638311
# min       17.600000           0.200000    0.000000    0.000000   33.330000
# 25%       70.600000          37.800000    3.220000    0.190000   71.650000
# 50%       92.500000         176.200000   10.420000    1.030000   85.700000
# 75%       98.000000         389.650000   20.000000    4.440000   95.440000
# max      100.000000        1035.600000   62.110000   50.680000  100.000000
# std       19.722173         227.991829   13.040402    8.361470   16.140835
#
#           Climate   Birthrate   Deathrate  Agriculture    Industry     Service
# count  205.000000  224.000000  223.000000   212.000000  211.000000  212.000000
# mean     2.139024   22.114732    9.241345     0.150844    0.282711    0.565283
# min      1.000000    7.290000    2.290000     0.000000    0.020000    0.062000
# 25%      2.000000   12.672500    5.910000     0.037750    0.193000    0.429250
# 50%      2.000000   18.790000    7.840000     0.099000    0.272000    0.571000
# 75%      3.000000   29.820000   10.605000     0.221000    0.341000    0.678500
# max      4.000000   50.730000   29.740000     0.769000    0.906000    0.954000
# std      0.699397   11.176716    4.990026     0.146798    0.138272    0.165841

# %% [markdown]
# ### Pregunta 1.7
#
# Según corresponda, realice un gráfico de distribución de densidad o histograma para describir 3 variables del `df` que usted crea más relevantes.
#
# ¿Por qué es importante analizar las distribuciones de las variables a utilizar en su modelo? Ejemplifique su respuesta con al menos una de las variables del df`.

# %%
sns.displot(df["Literacy (%)"])
plt.title("Distribución del Porcentaje de Alfabetización", fontsize=14)
plt.xlabel("Porcentaje de Alfabetización", fontsize=12)
plt.ylabel("Frecuencia de países", fontsize=12)
# Out:
# Text(5.069444444444445, 0.5, 'Frecuencia de países')

# %%
sns.displot(df["Industry"])
plt.title("Distribución del nivel de industrialización", fontsize=14)
plt.xlabel("Tamaño del sector industrial", fontsize=12)
plt.ylabel("Frecuencia de países", fontsize=12)
# Out:
# Text(13.819444444444445, 0.5, 'Frecuencia de países')

# %%
sns.displot(df["Service"])
plt.title("Distribución del sector Servicios", fontsize=14)
plt.xlabel("Tamaño del sector servicios", fontsize=12)
plt.ylabel("Frecuencia de países", fontsize=12)
# Out:
# Text(13.819444444444445, 0.5, 'Frecuencia de países')

# %% [markdown]
# ---
#
# Es importante analizar las distribuciones de las variables del modelo, para así entender como se construyen los datos sobre los que se construye el modelo. Por ejemplo, si alguna variable muy relevante tuviera una distribución muy extraña, podría indicar posibles sesgos del modelo. Además, sirve para tener una idea de qué correlaciones o tendencias podrían estar sucediendo con relación a nuestra variable que deseamos entender.
#
# En este caso, para analizar el nivel de desarrollo de un país, podemos guiarnos por sus variables explicativas, como por ejemplo el nivel de
# servicios del país. A medida que un país se desarrolla naturalmente la economia se centra en los servicios que aumentan la productividad o servicios de ocio que pueden ser pagados por la mayor riqueza, por eso es un buen indicativo el analizar su distribución. Como se puede ver, la distribución parece bastante normal, por lo que podemos tener mayor confianza de que puede ser una variable más precisa en el modelo.
#
#
# ---

# %% [markdown]
# ### Pregunta 1.8
#
# El df contiene variables con missing values (`NaN`). Impute los `NaN` con el método que estime conveniente, justificando su decisión.
#
# ¿Es pertinente eliminar alguna de estas variables? Hágalo si es el caso.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                227 non-null    datetime64[ns]
#  1   Country                             227 non-null    object
#  2   Region                              227 non-null    object
#  3   Population                          227 non-null    int64
#  4   Area (sq. mi.)                      227 non-null    int64
#  5   Pop. Density (per sq. mi.)          227 non-null    float64
#  6   Coastline (coast/area ratio)        227 non-null    float64
#  7   Net migration                       224 non-null    float64
#  8   Infant mortality (per 1000 births)  224 non-null    float64
#  9   GDP ($ per capita)                  226 non-null    float64
#  10  Literacy (%)                        209 non-null    float64
#  11  Phones (per 1000)                   223 non-null    float64
#  12  Arable (%)                          225 non-null    float64
#  13  Crops (%)                           225 non-null    float64
#  14  Other (%)                           225 non-null    float64
#  15  Climate                             205 non-null    float64
#  16  Birthrate                           224 non-null    float64
#  17  Deathrate                           223 non-null    float64
#  18  Agriculture                         212 non-null    float64
#  19  Industry                            211 non-null    float64
#  20  Service                             212 non-null    float64
# dtypes: datetime64[ns](1), float64(16), int64(2), object(2)
# memory usage: 37.4+ KB

# %%
cols = ["Net migration", "Infant mortality (per 1000 births)","GDP ($ per capita)","Literacy (%)","Phones (per 1000)","Arable (%)","Crops (%)","Other (%)","Climate","Birthrate","Deathrate","Agriculture","Industry","Service"]
df[cols] = df[cols].fillna(df.groupby("Region")[cols].transform("mean"))

# %% [markdown]
# ---
#
#
# El dataframe contiene 227 datos, vemos que la columna que más datos faltantes tiene es analfabetismo, con un total de 16 datos faltantes.
# Sin embargo, esto no llega a ser el 10% del total de datos, por lo que no representa una amenaza nuestro analisis. Para solucionar esto, vamos a imputar para cada país, la media de los datos de su región cuando presenta un dato NA. Con esta estimación, nos asemejamos a un dato mucho más plausible que solo colocar la media mundial, lo que se refuerza al reconocer la correlación que existe en estás metricas por región. Además, como el dato será un poco más preciso,
# se reduce el impacto en la varianza.
#
#
#
# ---

# %% [markdown]
# ### Pregunta 1.9
#
# ¿Cómo distribuye el `GDP ($ per capita)` en diferentes **regiones**? Defina una forma ilustrativa de gráficar el `GDP ($ per capita)` para todas las regiones en un mismo gráfico. Interprételo.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Region", y="GDP ($ per capita)", palette="Set2")
plt.title("Distribución del PIB per cápita por región")
plt.xticks(rotation=45)  # Rota los nombres de las regiones si son muchos
plt.ylabel("PIB per cápita ($)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
#
# Vemos que los datos atipicos primeramente son más comunes en las regiones pobres, lideradas por el africa sub-sahariana. Una excepción interesante se produce principalmente en western europe, lo que es probable que se deba a un país pequeño que sobreestime el pib percapita por algun arreglo estadistico, pero que se eliminaria al usar el PNN. Además, existe una cierta homogeneidad por región, siendo sin sorpresa norteamerica y western europe las regiones más ricas. Por ultimo, se puede apreciar que existe una diferencia amplia entre la mediana de las regiones ricas y las que están en desarrollo, lo que evidencia que aunque algunos paises están logrando aumentar sus ingresos, estos casos no son representativos de sus regiones, ya que la mediana aun se encuentra muy abajo.
#
#
# ---

# %% [markdown]
# ### Pregunta 1.10
#
# Supongamos que `GDP ($ per capita)` es su variable objetivo. Estudie la correlación de esta variable con el resto de las variables del `df`. ¿Por qué es importante analizar la correlación entre las variables?

# %%
#Eliminamos la variable date ya que no la ocuparemos más adelante, también se pudo excluir de otras maneras, pero esto es lo más rapido
subset_date = df["date"]
df=df.drop("date",axis=1)
df[df.dtypes[df.dtypes != "object"].index].corr()["GDP ($ per capita)"]
# Out:
# Population                           -0.038853
# Area (sq. mi.)                        0.072497
# Pop. Density (per sq. mi.)            0.196099
# Coastline (coast/area ratio)          0.049625
# Net migration                         0.383707
# Infant mortality (per 1000 births)   -0.596963
# GDP ($ per capita)                    1.000000
# Literacy (%)                          0.515455
# Phones (per 1000)                     0.830684
# Arable (%)                            0.023196
# Crops (%)                            -0.218445
# Other (%)                             0.094427
# Climate                               0.378147
# Birthrate                            -0.643247
# Deathrate                            -0.196066
# Agriculture                          -0.584562
# Industry                             -0.038022
# Service                               0.553063
# Name: GDP ($ per capita), dtype: float64

# %% [markdown]
# ---
#
# Es muy importante estudiar las correlaciones, puesto que es el primer proxy que tenemos para explicar la causalidad de una variable, o al menos que variables son relevantes. Por ello es importante esta tabla, ya que nos da una guia de cuales son las variables que debemos analizar para intentar aislar la causalidad, en caso que exista
#
#
# ---

# %% [markdown]
# ### Pregunta 1.11
#
# Realice tres _scatterplots_ (uno por variable) de las tres variables con la mayor correlación con la variable objetivo.
#
# Utilizando los parámetros de la función con la que hizo los _scatterplots_, coloque un título a cada gráfico y agregue colores a los _data points_ del _scatterplot_- Use colores diferentes por cada gráfico.

# %%
corr_per_capita= df[df.dtypes[df.dtypes != "object"].index].corr()["GDP ($ per capita)"].abs()
corr_per_capita.sort_values(ascending=False).head(4) #ordenamos de mayor a menor

#Con esto obtenemos las 3 variables con mayor correlación, excluyendo a si misma
# Out:
# GDP ($ per capita)                    1.000000
# Phones (per 1000)                     0.830684
# Birthrate                             0.643247
# Infant mortality (per 1000 births)    0.596963
# Name: GDP ($ per capita), dtype: float64

# %%
#Ahora graficamos las 3 variables encontradas en el paso anterior
df.plot.scatter(
    x="Phones (per 1000)",
    y="GDP ($ per capita)",
    title="Relación entre Teléfonos por 1000 habitantes y PIB per cápita",
    color="blue",  # Cambia a otro color si lo deseas
    alpha=0.6  # Ajusta la transparencia para visualizar mejor los puntos
)

plt.xlabel("Teléfonos por 1000 habitantes")
plt.ylabel("PIB per cápita ($)")
plt.grid(True)  # Agrega una cuadrícula para mejorar la visualización
plt.show()

df.plot.scatter(
    x="Birthrate",
    y="GDP ($ per capita)",
    title="Relación entre tasa de natalidad  y PIB per cápita",
    color="red",  # Cambia a otro color si lo deseas
    alpha=0.6  # Ajusta la transparencia para visualizar mejor los puntos
)

plt.xlabel("Servicios")
plt.ylabel("PIB per cápita ($)")
plt.grid(True)  # Agrega una cuadrícula para mejorar la visualización
plt.show()

df.plot.scatter(
    x="Infant mortality (per 1000 births)",
    y="GDP ($ per capita)",
    title="Relación entre mortalidad infantil y PIB per cápita",
    color="green",  # Cambia a otro color si lo deseas
    alpha=0.6  # Ajusta la transparencia para visualizar mejor los puntos
)

plt.xlabel("mortalidad infantil por 1000 habitantes")
plt.ylabel("PIB per cápita ($)")
plt.grid(True)  # Agrega una cuadrícula para mejorar la visualización
plt.show()

# %% [markdown]
# ### Pregunta 1.12
#
# Cree una nueva columna `GDP (%)` que represente el GDP total de cada pais (no per capita) y agreguela al dataframe.

# %%
df["GDP (%)"]=df["GDP ($ per capita)"]*df["Population"]
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry   Service       GDP (%)
# 0      46.60      20.34     0.380000  0.240000  0.380000  2.173990e+10
# 1      15.11       5.22     0.232000  0.188000  0.579000  1.611745e+10
# 2      17.14       4.61     0.101000  0.600000  0.298000  1.975805e+11
# 3      22.46       3.27     0.175125  0.215250  0.608938  4.623520e+08
# 4       8.71       6.25     0.044480  0.246083  0.714625  1.352819e+09

# %% [markdown]
# ### Pregunta 1.13
#
# Repita el análisis de correlaciones para `GDP ($)` excluyendo `GDP ($ per capita)` del análisis. ¿Cambian las variables que más correlacionan? Justifique.

# %%
df2=df.drop("GDP ($ per capita)",axis=1)

corr_GDP= df2[df2.dtypes[df2.dtypes != "object"].index].corr()["GDP (%)"].abs()

corr_GDP.sort_values(ascending=False).head(4)
#Obtenemos la lista de los 3 que mayor correlaciona, exluyendo a el mismo
# Out:
# GDP (%)              1.000000
# Population           0.639528
# Area (sq. mi.)       0.556396
# Phones (per 1000)    0.233041
# Name: GDP (%), dtype: float64

# %% [markdown]
# ---
#
#
# Cambián las variables que más correlacionan, porque ya no se controla por la cantidad de personas del pais. Por ejemplo, mientras para el GDP per capita importaba si al añadir una persona más, esta era más productiva que el promedio o no, para el GDP solo importa que hayan más personas. Por eso no es de extrañar que los primeras 2 variables que más correlacionan sean población y Area, que ayudan a aumentar el GDP por su mera definición (puesto que hay más recursos en la economía). También es importante mencionar, que se mantiene la alta correlacion de conectividad (teléfonos per 1000) que existia con el GDP per capita. Aunque pasa del primer lugar con 0.8 de correlación anteriormente, a un 0.23
#
# ---

# %% [markdown]
# ### Pregunta 1.14
#
# Detecte las observaciones outliers de las tres variables seleccionadas en la pregunta anterior. Además, impute estas observaciones si usted lo considera necesario. Justifique su decisión.

# %%
def identify_outliers(df, col):
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  df_outliers = df[(df[col] < Q1 - 1.5 * IQR) | (df[col] > Q3 + 1.5 * IQR)]
  return df_outliers

# %%
columnas = ["Population", "Area (sq. mi.)", "Phones (per 1000)"]

df_aux1 = identify_outliers(df, "Population")
df_aux2 = identify_outliers(df, "Area (sq. mi.)")
df_aux3 = identify_outliers(df, "Phones (per 1000)")

# %% [markdown]
#  Primero miramos los outliers de cada variable

# %%
df_aux1
# Out:
#                Country                               Region  Population  \
# 16         Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 27             Brazil               LATIN AMER. & CARIB       188078227
# 32              Burma         ASIA (EX. NEAR EAST)             47382633
# 42              China         ASIA (EX. NEAR EAST)           1313973713
# 43           Colombia               LATIN AMER. & CARIB        43593035
# 45   Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 60              Egypt   NORTHERN AFRICA                        78887007
# 65           Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 69             France   WESTERN EUROPE                         60876136
# 76            Germany   WESTERN EUROPE                         82422299
# 94              India         ASIA (EX. NEAR EAST)           1095351995
# 95          Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96               Iran         ASIA (EX. NEAR EAST)             68688433
# 101             Italy   WESTERN EUROPE                         58133509
# 103             Japan         ASIA (EX. NEAR EAST)            127463611
# 110      Korea, South         ASIA (EX. NEAR EAST)             48846823
# 135            Mexico               LATIN AMER. & CARIB       107449525
# 152           Nigeria   SUB-SAHARAN AFRICA                    131859731
# 156          Pakistan         ASIA (EX. NEAR EAST)            165803560
# 162       Philippines         ASIA (EX. NEAR EAST)             89468677
# 169            Russia                  C.W. OF IND. STATES    142893540
# 189      South Africa   SUB-SAHARAN AFRICA                     44187637
# 201          Thailand         ASIA (EX. NEAR EAST)             64631595
# 206            Turkey   NEAR EAST                              70413958
# 211           Ukraine                  C.W. OF IND. STATES     46710816
# 213    United Kingdom   WESTERN EUROPE                         60609153
# 214     United States   NORTHERN AMERICA                      298444215
# 219           Vietnam         ASIA (EX. NEAR EAST)             84402966
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 16           144000                      1023.4                          0.40
# 27          8511965                        22.1                          0.09
# 32           678500                        69.8                          0.28
# 42          9596960                       136.9                          0.15
# 43          1138910                        38.3                          0.28
# 45          2345410                        26.7                          0.00
# 60          1001450                        78.8                          0.24
# 65          1127127                        66.3                          0.00
# 69           547030                       111.3                          0.63
# 76           357021                       230.9                          0.67
# 94          3287590                       333.2                          0.21
# 95          1919440                       127.9                          2.85
# 96          1648000                        41.7                          0.15
# 101          301230                       193.0                          2.52
# 103          377835                       337.4                          7.87
# 110           98480                       496.0                          2.45
# 135         1972550                        54.5                          0.47
# 152          923768                       142.7                          0.09
# 156          803940                       206.2                          0.13
# 162          300000                       298.2                         12.10
# 169        17075200                         8.4                          0.22
# 189         1219912                        36.2                          0.23
# 201          514000                       125.7                          0.63
# 206          780580                        90.2                          0.92
# 211          603700                        77.4                          0.46
# 213          244820                       247.6                          5.08
# 214         9631420                        31.0                          0.21
# 219          329560                       256.1                          1.05
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 16           -0.71                               62.60              1900.0
# 27           -0.03                               29.61              7600.0
# 32           -1.80                               67.24              1800.0
# 42           -0.40                               24.18              5000.0
# 43           -0.31                               20.97              6300.0
# 45            0.00                               94.69               700.0
# 60           -0.22                               32.59              4000.0
# 65            0.00                               95.32               700.0
# 69            0.66                                4.26             27600.0
# 76            2.18                                4.16             27600.0
# 94           -0.07                               56.29              2900.0
# 95            0.00                               35.60              3200.0
# 96           -0.84                               41.58              7000.0
# 101           2.07                                5.94             26700.0
# 103           0.00                                3.26             28200.0
# 110           0.00                                7.05             17800.0
# 135          -4.87                               20.91              9000.0
# 152           0.26                               98.80               900.0
# 156          -2.77                               72.44              2100.0
# 162          -1.50                               23.51              4600.0
# 169           1.02                               15.39              8900.0
# 189          -0.29                               61.81             10700.0
# 201           0.00                               20.48              7400.0
# 206           0.00                               41.04              6700.0
# 211          -0.39                               20.34              5400.0
# 213           2.19                                5.16             27700.0
# 214           3.41                                6.50             37800.0
# 219          -0.45                               25.95              2500.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 16           43.1                7.3       62.11       3.07      34.82
# 27           86.4              225.3        6.96       0.90      92.15
# 32           85.3               10.1       15.19       0.97      83.84
# 42           90.9              266.7       15.40       1.25      83.35
# 43           92.5              176.2        2.42       1.67      95.91
# 45           65.5                0.2        2.96       0.52      96.52
# 60           57.7              131.8        2.87       0.48      96.65
# 65           42.7                8.2       10.71       0.75      88.54
# 69           99.0              586.4       33.53       2.07      64.40
# 76           99.0              667.9       33.85       0.59      65.56
# 94           59.5               45.4       54.40       2.74      42.86
# 95           87.9               52.0       11.32       7.23      81.45
# 96           79.4              276.4        8.72       1.39      89.89
# 101          98.6              430.9       27.79       9.53      62.68
# 103          99.0              461.2       12.19       0.96      86.85
# 110          97.9              486.1       17.18       1.95      80.87
# 135          92.2              181.6       12.99       1.31      85.70
# 152          68.0                9.3       31.29       2.96      65.75
# 156          45.7               31.8       27.87       0.87      71.26
# 162          92.6               38.4       18.95      16.77      64.28
# 169          99.6              280.6        7.33       0.11      92.56
# 189          86.4              107.0       12.08       0.79      87.13
# 201          92.6              108.9       29.36       6.46      64.18
# 206          86.5              269.5       30.93       3.31      65.76
# 211          99.7              259.9       56.21       1.61      42.18
# 213          99.0              543.5       23.46       0.21      76.33
# 214          97.0              898.0       19.13       0.22      80.65
# 219          90.3              187.7       19.97       5.95      74.08
#
#       Climate  Birthrate  Deathrate  Agriculture  Industry  Service  \
# 16   2.000000      29.80       8.27        0.199     0.198    0.603
# 27   2.000000      16.56       6.17        0.084     0.400    0.516
# 32   2.000000      17.91       9.83        0.564     0.082    0.353
# 42   1.500000      13.25       6.97        0.125     0.473    0.403
# 43   2.000000      20.48       5.58        0.125     0.342    0.533
# 45   2.000000      43.69      13.27        0.550     0.110    0.340
# 60   1.000000      22.94       5.23        0.149     0.357    0.493
# 65   2.000000      37.98      14.86        0.475     0.099    0.426
# 69   4.000000      11.99       9.14        0.022     0.214    0.764
# 76   3.000000       8.25      10.62        0.009     0.296    0.695
# 94   2.500000      22.01       8.18        0.186     0.276    0.538
# 95   2.000000      20.34       6.25        0.134     0.458    0.408
# 96   1.000000      17.00       5.55        0.116     0.424    0.460
# 101  3.095238       8.72      10.40        0.021     0.291    0.688
# 103  3.000000       9.37       9.16        0.017     0.258    0.725
# 110  3.000000      10.00       5.85        0.033     0.403    0.563
# 135  1.500000      20.69       4.74        0.038     0.259    0.702
# 152  1.500000      40.43      16.94        0.269     0.487    0.244
# 156  1.000000      29.74       8.23        0.216     0.251    0.533
# 162  2.000000      24.89       5.41        0.144     0.326    0.530
# 169  2.550000       9.95      14.65        0.054     0.371    0.575
# 189  1.000000      18.20      22.00        0.025     0.303    0.671
# 201  2.000000      13.87       7.04        0.099     0.441    0.460
# 206  3.000000      16.62       5.97        0.117     0.298    0.585
# 211  3.000000       8.82      14.39        0.187     0.452    0.361
# 213  3.000000      10.71      10.13        0.005     0.237    0.758
# 214  3.000000      14.14       8.26        0.010     0.204    0.787
# 219  2.000000      16.86       6.22        0.209     0.410    0.381
#
#           GDP (%)
# 16   2.799942e+11
# 27   1.429395e+12
# 32   8.528874e+10
# 42   6.569869e+12
# 43   2.746361e+11
# 45   4.386239e+10
# 60   3.155480e+11
# 65   5.234459e+10
# 69   1.680181e+12
# 76   2.274855e+12
# 94   3.176521e+12
# 95   7.854488e+11
# 96   4.808190e+11
# 101  1.552165e+12
# 103  3.594474e+12
# 110  8.694734e+11
# 135  9.670457e+11
# 152  1.186738e+11
# 156  3.481875e+11
# 162  4.115559e+11
# 169  1.271753e+12
# 189  4.728077e+11
# 201  4.782738e+11
# 206  4.717735e+11
# 211  2.522384e+11
# 213  1.678874e+12
# 214  1.128119e+13
# 219  2.110074e+11

# %%
df_aux2
# Out:
#                Country                               Region  Population  \
# 2             Algeria   NORTHERN AFRICA                        32930091
# 5              Angola   SUB-SAHARAN AFRICA                     12127071
# 8           Argentina               LATIN AMER. & CARIB        39921833
# 11          Australia   OCEANIA                                20264082
# 24            Bolivia               LATIN AMER. & CARIB         8989046
# 27             Brazil               LATIN AMER. & CARIB       188078227
# 36             Canada   NORTHERN AMERICA                       33098932
# 40               Chad   SUB-SAHARAN AFRICA                      9944201
# 42              China         ASIA (EX. NEAR EAST)           1313973713
# 43           Colombia               LATIN AMER. & CARIB        43593035
# 45   Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 65           Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 80          Greenland   NORTHERN AMERICA                          56361
# 94              India         ASIA (EX. NEAR EAST)           1095351995
# 95          Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96               Iran         ASIA (EX. NEAR EAST)             68688433
# 106        Kazakhstan                  C.W. OF IND. STATES     15233244
# 118             Libya   NORTHERN AFRICA                         5900754
# 128              Mali   SUB-SAHARAN AFRICA                     11716829
# 135            Mexico               LATIN AMER. & CARIB       107449525
# 139          Mongolia         ASIA (EX. NEAR EAST)              2832224
# 151             Niger   SUB-SAHARAN AFRICA                     12525094
# 161              Peru               LATIN AMER. & CARIB        28302603
# 169            Russia                  C.W. OF IND. STATES    142893540
# 179      Saudi Arabia   NEAR EAST                              27019731
# 189      South Africa   SUB-SAHARAN AFRICA                     44187637
# 192             Sudan   SUB-SAHARAN AFRICA                     41236378
# 214     United States   NORTHERN AMERICA                      298444215
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 2           2381740                        13.8                          0.04
# 5           1246700                         9.7                          0.13
# 8           2766890                        14.4                          0.18
# 11          7686850                         2.6                          0.34
# 24          1098580                         8.2                          0.00
# 27          8511965                        22.1                          0.09
# 36          9984670                         3.3                          2.02
# 40          1284000                         7.7                          0.00
# 42          9596960                       136.9                          0.15
# 43          1138910                        38.3                          0.28
# 45          2345410                        26.7                          0.00
# 65          1127127                        66.3                          0.00
# 80          2166086                         0.0                          2.04
# 94          3287590                       333.2                          0.21
# 95          1919440                       127.9                          2.85
# 96          1648000                        41.7                          0.15
# 106         2717300                         5.6                          0.00
# 118         1759540                         3.4                          0.10
# 128         1240000                         9.5                          0.00
# 135         1972550                        54.5                          0.47
# 139         1564116                         1.8                          0.00
# 151         1267000                         9.9                          0.00
# 161         1285220                        22.0                          0.19
# 169        17075200                         8.4                          0.22
# 179         1960582                        13.8                          0.13
# 189         1219912                        36.2                          0.23
# 192         2505810                        16.5                          0.03
# 214         9631420                        31.0                          0.21
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 2            -0.39                               31.00              6000.0
# 5             0.00                              191.19              1900.0
# 8             0.61                               15.18             11200.0
# 11            3.98                                4.69             29000.0
# 24           -1.32                               53.11              2400.0
# 27           -0.03                               29.61              7600.0
# 36            5.96                                4.75             29800.0
# 40           -0.11                               93.82              1200.0
# 42           -0.40                               24.18              5000.0
# 43           -0.31                               20.97              6300.0
# 45            0.00                               94.69               700.0
# 65            0.00                               95.32               700.0
# 80           -8.37                               15.82             20000.0
# 94           -0.07                               56.29              2900.0
# 95            0.00                               35.60              3200.0
# 96           -0.84                               41.58              7000.0
# 106          -3.35                               29.21              6300.0
# 118           0.00                               24.60              6400.0
# 128          -0.33                              116.79               900.0
# 135          -4.87                               20.91              9000.0
# 139           0.00                               53.79              1800.0
# 151          -0.67                              121.69               800.0
# 161          -1.05                               31.94              5100.0
# 169           1.02                               15.39              8900.0
# 179          -2.71                               13.24             11800.0
# 189          -0.29                               61.81             10700.0
# 192          -0.02                               62.50              1900.0
# 214           3.41                                6.50             37800.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 2           70.00               78.1        3.22       0.25      96.53
# 5           42.00                7.8        2.41       0.24      97.35
# 8           97.10              220.4       12.31       0.48      87.21
# 11         100.00              565.5        6.55       0.04      93.41
# 24          87.20               71.9        2.67       0.19      97.14
# 27          86.40              225.3        6.96       0.90      92.15
# 36          97.00              552.2        4.96       0.02      95.02
# 40          47.50                1.3        2.86       0.02      97.12
# 42          90.90              266.7       15.40       1.25      83.35
# 43          92.50              176.2        2.42       1.67      95.91
# 45          65.50                0.2        2.96       0.52      96.52
# 65          42.70                8.2       10.71       0.75      88.54
# 80          97.75              448.9        0.00       0.00     100.00
# 94          59.50               45.4       54.40       2.74      42.86
# 95          87.90               52.0       11.32       7.23      81.45
# 96          79.40              276.4        8.72       1.39      89.89
# 106         98.40              164.1        7.98       0.05      91.97
# 118         82.60              127.1        1.03       0.19      98.78
# 128         46.40                6.4        3.82       0.03      96.15
# 135         92.20              181.6       12.99       1.31      85.70
# 139         97.80               55.1        0.77       0.00      99.23
# 151         17.60                1.9        3.54       0.01      96.45
# 161         90.90               79.5        2.89       0.40      96.71
# 169         99.60              280.6        7.33       0.11      92.56
# 179         78.80              140.6        1.67       0.09      98.24
# 189         86.40              107.0       12.08       0.79      87.13
# 192         61.10               16.3        6.83       0.18      92.99
# 214         97.00              898.0       19.13       0.22      80.65
#
#       Climate  Birthrate  Deathrate  Agriculture  Industry  Service  \
# 2    1.000000      17.14       4.61        0.101  0.600000    0.298
# 5    1.885417      45.11      24.20        0.096  0.658000    0.246
# 8    3.000000      16.73       7.55        0.095  0.358000    0.547
# 11   1.000000      12.14       7.51        0.038  0.262000    0.700
# 24   1.500000      23.30       7.53        0.128  0.352000    0.520
# 27   2.000000      16.56       6.17        0.084  0.400000    0.516
# 36   2.000000      10.78       7.80        0.022  0.294000    0.684
# 40   2.000000      45.73      16.38        0.335  0.259000    0.406
# 42   1.500000      13.25       6.97        0.125  0.473000    0.403
# 43   2.000000      20.48       5.58        0.125  0.342000    0.533
# 45   2.000000      43.69      13.27        0.550  0.110000    0.340
# 65   2.000000      37.98      14.86        0.475  0.099000    0.426
# 80   1.000000      15.93       7.84        0.014  0.199333    0.787
# 94   2.500000      22.01       8.18        0.186  0.276000    0.538
# 95   2.000000      20.34       6.25        0.134  0.458000    0.408
# 96   1.000000      17.00       5.55        0.116  0.424000    0.460
# 106  4.000000      16.00       9.42        0.067  0.386000    0.547
# 118  1.500000      26.49       3.48        0.076  0.499000    0.425
# 128  2.000000      49.82      16.89        0.450  0.170000    0.380
# 135  1.500000      20.69       4.74        0.038  0.259000    0.702
# 139  1.000000      21.59       6.95        0.206  0.214000    0.580
# 151  1.000000      50.73      20.91        0.390  0.170000    0.440
# 161  1.500000      20.48       6.23        0.080  0.270000    0.650
# 169  2.550000       9.95      14.65        0.054  0.371000    0.575
# 179  1.000000      29.34       2.58        0.033  0.613000    0.354
# 189  1.000000      18.20      22.00        0.025  0.303000    0.671
# 192  2.000000      34.53       8.97        0.387  0.203000    0.410
# 214  3.000000      14.14       8.26        0.010  0.204000    0.787
#
#           GDP (%)
# 2    1.975805e+11
# 5    2.304143e+10
# 8    4.471245e+11
# 11   5.876584e+11
# 24   2.157371e+10
# 27   1.429395e+12
# 36   9.863482e+11
# 40   1.193304e+10
# 42   6.569869e+12
# 43   2.746361e+11
# 45   4.386239e+10
# 65   5.234459e+10
# 80   1.127220e+09
# 94   3.176521e+12
# 95   7.854488e+11
# 96   4.808190e+11
# 106  9.596944e+10
# 118  3.776483e+10
# 128  1.054515e+10
# 135  9.670457e+11
# 139  5.098003e+09
# 151  1.002008e+10
# 161  1.443433e+11
# 169  1.271753e+12
# 179  3.188328e+11
# 189  4.728077e+11
# 192  7.834912e+10
# 214  1.128119e+13

# %%
df_aux3
# Out:
#      Country                               Region  Population  Area (sq. mi.)  \
# 138  Monaco   WESTERN EUROPE                            32543               2
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 138                     16271.5                         205.0           7.75
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 138                                5.43             27000.0          99.0
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)   Climate  Birthrate  \
# 138             1035.6         0.0        0.0      100.0  3.095238       9.19
#
#      Deathrate  Agriculture  Industry   Service      GDP (%)
# 138      12.91         0.17  0.246083  0.714625  878661000.0

# %% [markdown]
# Ahora vamos a graficar los outliers del df

# %%
corr_sin_gdp_per_capita_head = corr_GDP.sort_values(ascending=False).head(4) #ordenamos de mayor a menor

#Generamos scatter plot para ver los outliers
df.plot.scatter(x="Population", y="GDP (%)")
df.plot.scatter(x="Area (sq. mi.)", y="GDP (%)")
df.plot.scatter(x="Phones (per 1000)", y="GDP (%)")
# Out:
# <Axes: xlabel='Phones (per 1000)', ylabel='GDP (%)'>

# %% [markdown]
# Ahora hacemos un df de solo los outliers

# %%
df_outliers = pd.concat([df_aux1, df_aux2, df_aux3], ignore_index=True)
df_outliers.drop_duplicates
df_outliers.head()
# Out:
#        Country                         Region  Population  Area (sq. mi.)  \
# 0  Bangladesh   ASIA (EX. NEAR EAST)            147365352          144000
# 1      Brazil         LATIN AMER. & CARIB       188078227         8511965
# 2       Burma   ASIA (EX. NEAR EAST)             47382633          678500
# 3       China   ASIA (EX. NEAR EAST)           1313973713         9596960
# 4    Colombia         LATIN AMER. & CARIB        43593035         1138910
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                      1023.4                          0.40          -0.71
# 1                        22.1                          0.09          -0.03
# 2                        69.8                          0.28          -1.80
# 3                       136.9                          0.15          -0.40
# 4                        38.3                          0.28          -0.31
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                               62.60              1900.0          43.1
# 1                               29.61              7600.0          86.4
# 2                               67.24              1800.0          85.3
# 3                               24.18              5000.0          90.9
# 4                               20.97              6300.0          92.5
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                7.3       62.11       3.07      34.82      2.0      29.80
# 1              225.3        6.96       0.90      92.15      2.0      16.56
# 2               10.1       15.19       0.97      83.84      2.0      17.91
# 3              266.7       15.40       1.25      83.35      1.5      13.25
# 4              176.2        2.42       1.67      95.91      2.0      20.48
#
#    Deathrate  Agriculture  Industry  Service       GDP (%)
# 0       8.27        0.199     0.198    0.603  2.799942e+11
# 1       6.17        0.084     0.400    0.516  1.429395e+12
# 2       9.83        0.564     0.082    0.353  8.528874e+10
# 3       6.97        0.125     0.473    0.403  6.569869e+12
# 4       5.58        0.125     0.342    0.533  2.746361e+11

# %% [markdown]
# Vemos también como quedó el df sin outliers.

# %%
df2=df[(df["Phones (per 1000)"]<800) & (df["Area (sq. mi.)"]<0.5*1e7) & (df["Population"]<0.22*1e9)]
df2.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry   Service       GDP (%)
# 0      46.60      20.34     0.380000  0.240000  0.380000  2.173990e+10
# 1      15.11       5.22     0.232000  0.188000  0.579000  1.611745e+10
# 2      17.14       4.61     0.101000  0.600000  0.298000  1.975805e+11
# 3      22.46       3.27     0.175125  0.215250  0.608938  4.623520e+08
# 4       8.71       6.25     0.044480  0.246083  0.714625  1.352819e+09

# %%
df2.plot.scatter(x="Population", y="GDP (%)")
df2.plot.scatter(x="Area (sq. mi.)", y="GDP (%)")
df2.plot.scatter(x="Phones (per 1000)", y="GDP (%)")
# Out:
# <Axes: xlabel='Phones (per 1000)', ylabel='GDP (%)'>

# %%
sns.boxplot(y=df["Phones (per 1000)"])
# Out:
# <Axes: ylabel='Phones (per 1000)'>

# %%
sns.boxplot(y=df["Area (sq. mi.)"])
# Out:
# <Axes: ylabel='Area (sq. mi.)'>

# %% [markdown]
# ---
#
#
# Viendo los outliers de las tres variables que más correlacionan con el GDP, nos llama la atención que son los paises mas grandes. Entonces, no es raro que, por ejemplo, la población de China o la India sean outliers de la variable población, puesto que sus valores son mucho más grandes que la media. Lo mismo sucede con países chicos como el vaticano o mónaco. Mirando la variable áre, vemos una situación similar.
#
# No obstante, los países con mayor área y/o población, son frecuentemente los ágentes más importantes de la economía mundial. Por ende, no contarlos en el análisis conllevaría a resultados completamente sesgados. Es por eso, que para tanto área como población, decidimos dejar los outliers en el dataset.
#
# La variable Phones per 1000 solo tiene un outlier, que es monaco. Como solo es un dato, también consideramos dejarlo para trabajar con el dataset original, puesto que no tendría casi ningun valor eliminarlo.
#
#
# ---

# %% [markdown]
# ### Pregunta 1.15
#
# En los ejemplos anteriores calculamos correlaciones para `GDP ($ per capita)` y `GDP ($)`. Genere un nuevo dataframe que tenga le variación porcentual de la correlación absoluta para cada una de las columnas de características, e.g., si la correlación en valor absoluto de `GDP ($ per capita)` vs `Industry` es 0.1 y la correlación `GDP ($)` vs `Industry` es 0.5, la variación deberá ser +500%. Dicha variación porcentual puede ser positiva o negativa, pero ordene los el dataframe de tal manera que la variación de correlación absoluta sea desendiente.

# %%
#Nos aseguramos que esten ordenadas de igual manera las correlaciones, y luego le aplicamos el cambio porcentual con valor absoluto
common_vars = corr_per_capita.index.intersection(corr_GDP.index)

# Subset con las variables comunes
corr_per_capita = corr_per_capita.loc[common_vars]
corr_gdp = corr_GDP.loc[common_vars]

cambio_pct = ((corr_gdp - corr_per_capita) / corr_per_capita) * 100

# Mostramos el resultado ordenado por valor absoluto. Utilizamos una variable auxiliar.
df_aux = cambio_pct.to_frame()
df_aux.columns = ["Cambio_porcentual"]
df_aux["key"] = abs(df_aux.Cambio_porcentual)
df_aux = df_aux.sort_values(by='key', ascending=False)
df_aux = df_aux.drop(columns=['key'])

df_aux
# Out:
#                                     Cambio_porcentual
# Population                                1546.002958
# Area (sq. mi.)                             667.469912
# Arable (%)                                 458.892975
# Net migration                              -85.533644
# Pop. Density (per sq. mi.)                 -85.473306
# Service                                    -84.476297
# Deathrate                                  -81.744379
# Literacy (%)                               -80.163739
# Infant mortality (per 1000 births)         -79.452280
# Agriculture                                -75.761331
# Birthrate                                  -74.060365
# Phones (per 1000)                          -71.945840
# Climate                                    -69.647409
# Crops (%)                                  -64.418555
# Other (%)                                  -31.728497
# Coastline (coast/area ratio)                31.406736
# Industry                                    25.127821

# %% [markdown]
# ### Pregunta 1.16
#
# Del resultado anterior, ¿qué caracerística del país tuvo una mayor diferencia absoluta el medir su correlación versus `GDP ($)` en vez de `GDP ($ per capita)`'. Interprete.

# %% [markdown]
# ---
#
#
# El mayor cambio porcentual se obtuvo en población, esto es claro debido a la relación clara que existe entre GDP y GDP per capita. En GDP per capita importa mucho el efecto marginal de cada una de las personas que se agrega a su calculo. Esto es lo contrario para GDP debido a que todo efecto marginal al agregar una persona termina aumentando el GDP.
#
#
# ---

# %% [markdown]
# ## EDA con diferentes fuentes de **información**

# %% [markdown]
# Una situación habitual en _Data Science: es el manejo de información de múltiples fuentes para un mismo propósito. En este sentido, de ahora en adelante agregaremos un dataframe adicional a nuestro set de información, disponible en [Github](https://raw.githubusercontent.com/datasets/gini-index/refs/heads/main/data/gini-index.csv). Lo llamaremos `df_gini`.
#
# Este dataset contiene información histórica del Índice de Gini (economía), el cual captura la desigualdad económica entre los quintiles de cada país. A mayor índice Gini, más desigual es un país en términos de ingresos. Para mayor información sobre los datos, puede dirigirse al [Repositorio](https://github.com/datasets/gini-index) completo. Para conocer más sobre el índice, una navegación por [Wikipedia](https://en.wikipedia.org/wiki/Gini_coefficient) debería ser suficiente.

# %% [markdown]
# ### Pregunta 2.0
#
# Cargue la base datos, asegúrese de que la variable de año esté en un formato de "fecha", y usando el diccionario de mapeo por inconsistencias de nombres, `country_name_mapping`, encuentre la forma de realizar un INNER JOIN entre ambas tablas, usando el nombre del país y el año de la observación como variables por las cuales hacer el JOIN. En el diccionario `country_name_mapping`, _keys_ corresponden a los valores de la tabla `df_gini` y _values_ a los de `df`.
#
# Llame al dataframe resultante `df_merged`.
#
# Si usted no se ha percatado, los nombres en la columna `Country` de `df` poseen espacios al final de estos. Elimine los espacios antes de realizar el INNER JOIN de interés (Hint: existe una función propia de las variables tipo `string` que realiza la labor de eliminar espacios al final de la palabra).

# %%
# NO MODIFICAR, pero sí ejecutar
country_name_mapping = {
    "Bahamas": "Bahamas, The",
    "Bosnia and Herzegovina": "Bosnia & Herzegovina",
    "Myanmar": "Burma",
    "Cape Verde": "Cabo Verde",
    "Central African Republic": "Central African Rep.",
    "Congo, Rep.": "Congo, Repub. of the",
    "Czechia": "Czech Republic",
    "Timor-Leste": "East Timor",
    "Egypt, Arab Rep.": "Egypt",
    "West Bank and Gaza": "Gaza Strip",
    "Iran, Islamic Rep.": "Iran",
    "Korea, Dem. People's Rep.": "Korea, North",
    "Korea, Rep.": "Korea, South",
    "Kyrgyz Republic": "Kyrgyzstan",
    "Lao PDR": "Laos",
    "North Macedonia": "Macedonia",
    "Micronesia, Fed. Sts.": "Micronesia, Fed. St.",
    "Russian Federation": "Russia",
    "St. Kitts and Nevis": "Saint Kitts & Nevis",
    "St. Lucia": "Saint Lucia",
    "St. Vincent and the Grenadines": "Saint Vincent and the Grenadines",
    "Slovak Republic": "Slovakia",
    "Eswatini": "Swaziland",
    "Syrian Arab Republic": "Syria",
    "Trinidad and Tobago": "Trinidad & Tobago",
    "Turkiye": "Turkey",
    "Venezuela, RB": "Venezuela",
    "Viet Nam": "Vietnam",
    "Yemen, Rep.": "Yemen"
}

# %%
url = "https://raw.githubusercontent.com/datasets/gini-index/refs/heads/main/data/gini-index.csv"
df_gini = pd.read_csv(url)

# %%
df_gini.Year = pd.to_datetime(df_gini.Year, format="%Y")

# %%
df_gini['Country Name'] = df_gini['Country Name'].replace(country_name_mapping)
df['Country'] = df['Country'].replace(country_name_mapping)

# %%
df = pd.concat([df, subset_date], axis=1)

# %%
df["Country"] = df["Country"].str.strip()
df_gini = df_gini.rename(columns={'Country Name': 'Country'})
df_gini = df_gini.rename(columns={'Year': 'date'})

# %%
df_merged = pd.merge(df, df_gini, on=['Country', 'date'], how='inner')

# %%
df_merged
# Out:
#            Country                               Region  Population  \
# 0        Argentina              LATIN AMER. & CARIB        39921833
# 1          Armenia                 C.W. OF IND. STATES      2976372
# 2          Austria  WESTERN EUROPE                          8192880
# 3          Belarus                 C.W. OF IND. STATES     10293011
# 4          Belgium  WESTERN EUROPE                         10379067
# ..             ...                                  ...         ...
# 62        Thailand        ASIA (EX. NEAR EAST)             64631595
# 63         Ukraine                 C.W. OF IND. STATES     46710816
# 64  United Kingdom  WESTERN EUROPE                         60609153
# 65   United States  NORTHERN AMERICA                      298444215
# 66         Uruguay              LATIN AMER. & CARIB         3431932
#
#     Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          2766890                        14.4                          0.18
# 1            29800                        99.9                          0.00
# 2            83870                        97.7                          0.00
# 3           207600                        49.6                          0.00
# 4            30528                       340.0                          0.22
# ..             ...                         ...                           ...
# 62          514000                       125.7                          0.63
# 63          603700                        77.4                          0.46
# 64          244820                       247.6                          5.08
# 65         9631420                        31.0                          0.21
# 66          176220                        19.5                          0.37
#
#     Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            0.61                               15.18             11200.0
# 1           -6.47                               23.28              3500.0
# 2            2.00                                4.66             30000.0
# 3            2.54                               13.37              6100.0
# 4            1.23                                4.68             29100.0
# ..            ...                                 ...                 ...
# 62           0.00                               20.48              7400.0
# 63          -0.39                               20.34              5400.0
# 64           2.19                                5.16             27700.0
# 65           3.41                                6.50             37800.0
# 66          -0.32                               11.95             12800.0
#
#     Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0           97.1              220.4       12.31       0.48      87.21
# 1           98.6              195.7       17.55       2.30      80.15
# 2           98.0              452.2       16.91       0.86      82.23
# 3           99.6              319.1       29.55       0.60      69.85
# 4           98.0              462.6       23.28       0.40      76.32
# ..           ...                ...         ...        ...        ...
# 62          92.6              108.9       29.36       6.46      64.18
# 63          99.7              259.9       56.21       1.61      42.18
# 64          99.0              543.5       23.46       0.21      76.33
# 65          97.0              898.0       19.13       0.22      80.65
# 66          98.0              291.4        7.43       0.23      92.34
#
#     Climate  Birthrate  Deathrate  Agriculture  Industry  Service  \
# 0       3.0      16.73       7.55        0.095     0.358    0.547
# 1       4.0      12.07       8.23        0.239     0.343    0.418
# 2       3.0       8.74       9.76        0.018     0.304    0.678
# 3       4.0      11.16      14.02        0.093     0.316    0.591
# 4       3.0      10.38      10.27        0.010     0.240    0.749
# ..      ...        ...        ...          ...       ...      ...
# 62      2.0      13.87       7.04        0.099     0.441    0.460
# 63      3.0       8.82      14.39        0.187     0.452    0.361
# 64      3.0      10.71      10.13        0.005     0.237    0.758
# 65      3.0      14.14       8.26        0.010     0.204    0.787
# 66      3.0      13.91       9.05        0.093     0.311    0.596
#
#          GDP (%)       date Country Code  Value
# 0   4.471245e+11 2007-01-01          ARG   46.3
# 1   1.041730e+10 2007-01-01          ARM   31.2
# 2   2.457864e+11 2007-01-01          AUT   30.6
# 3   6.278737e+10 2007-01-01          BLR   29.6
# 4   3.020308e+11 2007-01-01          BEL   29.2
# ..           ...        ...          ...    ...
# 62  4.782738e+11 2007-01-01          THA   39.8
# 63  2.522384e+11 2007-01-01          UKR   27.0
# 64  1.678874e+12 2007-01-01          GBR   34.4
# 65  1.128119e+13 2007-01-01          USA   40.8
# 66  4.392873e+10 2007-01-01          URY   46.4
#
# [67 rows x 24 columns]

# %% [markdown]
# ### Pregunta 2.1
#
# Repita el ejercicio de la obtención de un ranking para las correlaciones absolutas, tal como lo hizo para el GDP per cápita. ¿Cuáles son las relaciones que más le sorprenden? ¿Cuáles son las que están en línea con lo que esperaba? Justifique para ambos casos.

# %%
df_merged = df_merged.rename(columns={"Value": "Gini"})
df_merged.Gini = df_merged.Gini.astype(float)
df_numeric = df_merged.select_dtypes(include=["number"])

corr_matrix = df_numeric.corr()
corr = corr_matrix["Gini"]

# Aquí tenemos las correlaciones, ordenamos por valor absoluto con la variable auxiliar.
corr = pd.DataFrame(corr)
corr["key"] = abs(corr["Gini"])
corr = corr.sort_values(by='key', ascending=False)
corr = corr.drop(columns=['key'])
corr
# Out:
#                                         Gini
# Gini                                1.000000
# Climate                            -0.497597
# Phones (per 1000)                  -0.404478
# GDP ($ per capita)                 -0.398683
# Birthrate                           0.377369
# Net migration                      -0.345544
# Arable (%)                         -0.342382
# Deathrate                          -0.324386
# Other (%)                           0.281669
# Area (sq. mi.)                      0.206807
# Infant mortality (per 1000 births)  0.203505
# Literacy (%)                       -0.179161
# Agriculture                         0.177731
# Coastline (coast/area ratio)       -0.170565
# Service                            -0.163238
# Crops (%)                           0.133987
# Population                          0.097588
# Pop. Density (per sq. mi.)         -0.071111
# GDP (%)                             0.046118
# Industry                           -0.032563

# %% [markdown]
# ---
#
#
# Primero, en línea con lo que esperábamos, el GDP per capita y la cantidad de teléfonos por 1000 personas, son muy determinantes para tener ginis bajos. Esto no es sorpresa, puesto que son indicadores de paises más ricos, que tendrán mayores posibilidades para invertir en reducir la desigualdad.
#
# Nos sorprende la variable clima, que está muy relacionada. A mejor clima, menor gini.Esto tal vez tenga otras variables explicativas relacionadas, que no están en el modelo. También, sorprendentemente population tiene una correlación muy baja, puesto que uno esperaría que países con mucha gente tuvieran mayor varianza en riqueza.
#
# ---

# %% [markdown]
# Finalmente, agregaremos una tercera base de datos al análisis, también disponible en [Github](https://raw.githubusercontent.com/datasets/co2-fossil-by-nation/refs/heads/main/data/fossil-fuel-co2-emissions-by-nation.csv) con su repectivo
# [Repositorio](https://github.com/datasets/co2-fossil-by-nation). Esta contiene emisiones de dióxido de carbono (CO2) total y por fuentes, desagregado por país. La base de datos contiene datos desde el siglo XVI y la frecuencia es anual.

# %% [markdown]
# ### Pregunta 2.2
#
# Cargue la base de datos llamándola `df_co2`. Asegúrese de que todas las variables estén en su correcto formato (años deben estar en un formato de fecha). ¿Qué cuidados identifica usted que debiésemos tener al momento de observar valores nulos en esta base de datos?
#
# Adicionalmente, para cada palabra en la columna `Country`, asegúrese de que la primera letra siempre sea mayúscula y que el resto de letras sean minúsculas (Hint: revise `methods` propios de las variables tipo `string`).
#
# Luego, reemplace valores en `df_co2["Country"]` según el mapping otorgado. En el diccionario `country_name_mapping_co2`, _keys_ corresponden a los valores de la tabla `df_co2` y _values_ a los de `df`.

# %%
# NO MODIFICAR, pero sí ejecutar
country_name_mapping_co2 = {
    "United States Of America": "United States",
    "France (Including Monaco)": "France",
    "Italy (Including San Marino)": "Italy",
    "Plurinational State Of Bolivia": "Bolivia",
    "Federal Republic Of Germany": "Germany",
    "Former German Democratic Republic": "Germany",
    "Republic Of Moldova": "Moldova",
    "United Republic Of Tanzania": "Tanzania",
    "Japan (Excluding The Ruyuku Islands)": "Japan",
    "Hong Kong Special Adminstrative Region Of China": "Hong Kong",
    "Peninsular Malaysia": "Malaysia",
    "Democratic Republic Of The Congo (Formerly Zaire)": "Congo, Dem. Rep.",
    "Brunei (Darussalam)": "Brunei",
    "Myanmar (Formerly Burma)": "Burma",
    "Syrian Arab Republic": "Syria",
    "Islamic Republic Of Iran": "Iran",
    "Republic Of Korea": "Korea, South",
    "Democratic People S Republic Of Korea": "Korea, North",
    "Russian Federation": "Russia",
    "Viet Nam": "Vietnam",
    "Yemen": "Yemen, Rep.",
    "Trinidad And Tobago": "Trinidad & Tobago",
    "Bahamas": "Bahamas, The",
    "Micronesia": "Micronesia, Fed. St.",
    "Slovakia": "Slovakia",
    "St. Vincent & The Grenadines": "Saint Vincent and the Grenadines",
    "Saint Lucia": "Saint Lucia",
    "Antigua & Barbuda": "Antigua & Barbuda",
    "Saint Kitts-Nevis-Anguilla": "Saint Kitts & Nevis",
    "Netherland Antilles And Aruba": "Netherlands Antilles",
    "Timor-Leste (Formerly East Timor)": "East Timor",
    "Macau Special Adminstrative Region Of China": "Macau",
    "Republic Of Cameroon": "Cameroon",
    "Republic Of Sudan": "Sudan",
    "Lao People S Democratic Republic": "Laos",
    "Libyan Arab Jamahiriyah": "Libya",
    "Cote D Ivoire": "Cote d'Ivoire",
    "British Virgin Islands": "British Virgin Is.",
    "Faeroe Islands": "Faroe Islands",
    "China (Mainland)": "China",
}

# %%
url = "https://raw.githubusercontent.com/datasets/co2-fossil-by-nation/refs/heads/main/data/fossil-fuel-co2-emissions-by-nation.csv"
df_co2 = pd.read_csv(url)

# %%
df_co2.Year = pd.to_datetime(df_co2.Year, format="%Y")

# %%
df_co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18769 entries, 0 to 18768
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         18769 non-null  datetime64[ns]
#  1   Country                      18769 non-null  object
#  2   Total                        18769 non-null  int64
#  3   Solid Fuel                   13078 non-null  float64
#  4   Liquid Fuel                  18150 non-null  float64
#  5   Gas Fuel                     10611 non-null  float64
#  6   Cement                       18252 non-null  float64
#  7   Gas Flaring                  2676 non-null   float64
#  8   Per Capita                   13245 non-null  float64
#  9   Bunker fuels (Not in Total)  18480 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 1.4+ MB

# %%
df_co2["Country"] = df_co2["Country"].str.title()
df_co2['Country'] = df_co2['Country'].replace(country_name_mapping_co2)

# %% [markdown]
# ---
#
#
# *Escriba* su respuesta y justificación en esta celda...
#
# ---

# %% [markdown]
# ### Pregunta 2.3
#
# En un mismo gráfico, grafique las series de emisiones totales de CO2 para los siguientes países:
#
# - Reino Unido
# - Canadá
# - Alemania
# - Francia
# - Estados Unidos
# - Brasil
# - China
# - Japón
# - India
#
#
# Para cada serie, añada una leyenda con el nombre del país.

# %%
df_co2
# Out:
#             Year                    Country  Total  Solid Fuel  Liquid Fuel  \
# 0     1751-01-01             United Kingdom   2552      2552.0          0.0
# 1     1752-01-01             United Kingdom   2553      2553.0          0.0
# 2     1753-01-01             United Kingdom   2553      2553.0          0.0
# 3     1754-01-01             United Kingdom   2554      2554.0          0.0
# 4     1755-01-01             United Kingdom   2555      2555.0          0.0
# ...          ...                        ...    ...         ...          ...
# 18764 2020-01-01                    Vietnam  94323     58902.0      18906.0
# 18765 2020-01-01  Wallis And Futuna Islands      7         NaN          7.0
# 18766 2020-01-01                Yemen, Rep.   2569        78.0       2213.0
# 18767 2020-01-01                     Zambia   2240       704.0       1223.0
# 18768 2020-01-01                   Zimbabwe   2150      1176.0        831.0
#
#        Gas Fuel   Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# 0           0.0      0.0          NaN         NaN                          0.0
# 1           0.0      0.0          NaN         NaN                          0.0
# 2           0.0      0.0          NaN         NaN                          0.0
# 3           0.0      0.0          NaN         NaN                          0.0
# 4           0.0      0.0          NaN         NaN                          0.0
# ...         ...      ...          ...         ...                          ...
# 18764    4621.0  11894.0          NaN    0.980455                        855.0
# 18765       NaN      NaN          NaN    0.574098                          1.0
# 18766      70.0    208.0          NaN    0.080461                         81.0
# 18767       NaN    313.0          NaN    0.120065                         15.0
# 18768       NaN    143.0          NaN    0.138667                         15.0
#
# [18769 rows x 10 columns]

# %%
unicos = list(set(df_co2.Country.tolist()))
unicos.sort()
print(unicos)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antarctic Fisheries', 'Antigua & Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire, Saint Eustatius, And Saba', 'Bosnia & Herzegovina', 'Botswana', 'Brazil', 'British Virgin Is.', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burma', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Colombia', 'Comoros', 'Congo', 'Congo, Dem. Rep.', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic', 'Czechoslovakia', 'Democratic Republic Of Vietnam', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'East & West Pakistan', 'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Federated States Of Micronesia', 'Federation Of Malaya-Singapore', 'Fiji', 'Finland', 'Former Democratic Yemen', 'Former Panama Canal Zone', 'Former Yemen', 'France', 'French Equatorial Africa', 'French Guiana', 'French Indo-China', 'French Polynesia', 'French West Africa', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guatemala', 'Guinea', 'Guinea Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle Of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, North', 'Korea, South', 'Kosovo', 'Kuwait', 'Kuwaiti Oil Fires', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Leeward Islands', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macau', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Moldova', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Namibia', 'Nauru', 'Nepal', 'Netherland Antilles', 'Netherlands', 'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norway', 'Occupied Palestinian Territory', 'Oman', 'Pacific Islands (Palau)', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Republic Of South Sudan', 'Republic Of South Vietnam', 'Reunion', 'Rhodesia-Nyasaland', 'Romania', 'Russia', 'Rwanda', 'Rwanda-Urundi', 'Ryukyu Islands', 'Sabah', 'Saint Helena', 'Saint Lucia', 'Saint Martin (Dutch Portion)', 'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome & Principe', 'Sarawak', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'St. Kitts-Nevis', 'St. Kitts-Nevis-Anguilla', 'St. Pierre & Miquelon', 'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanganyika', 'Tanzania', 'Thailand', 'Togo', 'Tonga', 'Trinidad & Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks And Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United Korea', 'United States', 'Uruguay', 'Ussr', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Wallis And Futuna Islands', 'Yemen, Rep.', 'Yugoslavia (Former Socialist Federal Republic)', 'Yugoslavia (Montenegro & Serbia)', 'Zambia', 'Zanzibar', 'Zimbabwe']

# %%
paises = ['United Kingdom','Canada','Germany','France','United States','Brazil','China','Japan','India']

# %%
df_subset = df_co2[df_co2["Country"].isin(paises)]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_subset, x="Year", y="Total", hue="Country", marker="o")

plt.title("Evolución de Emisiones de CO₂ por País")
plt.xlabel("Año")
plt.ylabel("Emisiones de CO₂")
plt.legend(title="Países")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pregunta 2.4
#
# Para el año 2007, por cada país realice un ranking de las fuentes con más emisiones de CO2 excluyendo las variables `Per Capita` y `Bunker fuels (Not in Total)`. Es decir, asigne un número de 1 a 5 a $\{$ `Solid Fuel`, `Liquid Fuel`, `Gas Fuel`, `Cement`, `Gas Flaring` $\}$, donde 1 es la mayor fuente de emisión de ese país en aquel año, y 5 indica que fue la menor; así para todos los países.
#
# Si en 2007 no se reporta una fuente de emisión para un país, por ejemplo, si emisiones de `Gas Flaring` no se reportara, entonces asigne números de 1 a 4 a las fuentes restantes. Análogo para un menor número de datos.
#
# Luego, por cada variable grafique un histograma de frecuencias del ranking que obtuvo la fuente emisión a lo largo de todos los países.
#
# ¿Cuál fue la fuente más contaminante en la mayoría de países en 2007?

# %%
df_subset = df_co2[df_co2["Year"].dt.year == 2007]

# %%
import math

# %%
def obtener_ranking(fila):

  a = float(fila["Solid Fuel"])
  b = float(fila["Liquid Fuel"])
  c = float(fila["Gas Fuel"])
  d = float(fila["Cement"])
  e = float(fila["Gas Flaring"])

  lista = [[a,"Solid Fuel"], [b,"Liquid Fuel"], [c,"Gas Fuel"], [d,"Cement"], [e,"Gas Flaring"]]
  lista_2 = []
  for item in lista:
    if math.isnan(item[0]):
      hola = 1
    else:
        lista_2.append(item)

  lista_ordenada = sorted(lista_2, key=lambda x: x[0], reverse=True)

  lista_final = [item[1] for item in lista_ordenada]

  return lista_final

df_subset["ranking"] = df_subset.apply(obtener_ranking, axis=1)

# %%
def expandir_ranking(fila,key):
  listado = fila["ranking"]
  if key not in listado:
    return 0
  else:
    indice = listado.index(key) + 1
    return indice

df_subset["rank_Solid Fuel"] = df_subset.apply(expandir_ranking,key = "Solid Fuel",axis=1)
df_subset["rank_Liquid Fuel"] = df_subset.apply(expandir_ranking,key = "Liquid Fuel",axis=1)
df_subset["rank_Gas Fuel"] = df_subset.apply(expandir_ranking,key = "Gas Fuel",axis=1)
df_subset["rank_Cement"] = df_subset.apply(expandir_ranking,key = "Cement",axis=1)
df_subset["rank_Gas Flaring"] = df_subset.apply(expandir_ranking,key = "Gas Flaring",axis=1)

# %%
variables_seleccionadas = ["rank_Solid Fuel", "rank_Liquid Fuel", "rank_Gas Fuel", "rank_Cement", "rank_Gas Flaring"]
df_subset[variables_seleccionadas] = df_subset[variables_seleccionadas].replace(0, pd.NA)

for x in variables_seleccionadas:
  df_subset[x].hist(figsize=(5, 2), bins=5, edgecolor="black")
  plt.tight_layout()
  plt.suptitle(f"Distribución {x}", fontsize=10, fontweight="bold")
  plt.show()

# %% [markdown]
# ¿Cuál fue la fuente más contaminante en la mayoría de países en 2007?
#
# ---
#
# La fuente más contaminante en la mayoría de los países en 2007 fueron los liquid fuels, llevandose el primer lugar en más de 150 paises de los 220 estudiados en ese año. El segundo lugar fue solid fuels, con aproximadamente 25 paises.
#
# ---

# %% [markdown]
# ### Pregunta 2.5
#
# Para cada serie de total de emisiones por país, calcule el cambio porcentual a través del tiempo. Realice imputación de missings si considera necesario, justificando su imputación. Si no lo considera necesario, también justifique (se evaluará un buen criterio fundamentado).
#
# Repita el ejercicio del gráfico de series de tiempo anterior, pero graficando los **cambios porcentuales** para años mayores o iguales a 1995. ¿Cómo interpretaría económicamente el shock sobre las emisiones de CO2 tanto en la crisis subprime como en la crisis del Covid-19?

# %%
df_co2 = df_co2.sort_values(by=['Country', 'Year'])
df_co2['cambio (%)'] = df_co2.groupby('Country')['Total'].pct_change() * 100
df_co2['Year'] = df_co2['Year'].dt.year

# %%
paises_seleccionados = ['United Kingdom', 'Canada', 'Germany',  "France",'United States',"Brazil", "China", "Japan",'India']

df_filtrado = df_co2[(df_co2['Country'].isin(paises_seleccionados)) & (df_co2['Year'] >= 1995)]


# Configuración del gráfico
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_filtrado, x='Year', y='cambio (%)', hue='Country', marker='o')

# Personalización
plt.title('Evolución de Emisiones de CO₂ por País')
plt.xlabel('Año')
plt.ylabel('Emisiones (Toneladas)')
plt.legend(title='País')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ---
#
#
# La crisis subprime (2007-2008) y la crisis del covid 19 (2020), se pueden ver claramente como una caída en las emisiones de CO2 para la mayoría de países. Primero en el 2008 aproximadamente, se ve como el cambio porcentual es negativo para la mayoría, incluso llegando a -10% para el Reino Unido. Esto muestra que la actividad económica se desaceleró y por lo tanto cayeron las emisiones.
#
# Lo mismo se puede ver en la pandemia del 2020. Parece ser que la caída en emisiones de CO2 fue más grande en la pandemía, donde se llega casi al -15% para algunos países.
#
# La interpretación económica del shock, es que a menor demanda o menor oferta (podría ser ambos en el 2008), hay una cantidad producida menor, que está asociada a una menor emision de co2 por parte de las empresas.
#
#
# ---

# %% [markdown]
# ### Pregunta 2.6
#
# Calcule el promedio a lo largo de toda la muestra ($\mathbb{E}[\cdot]$) para el cambio porcentual de cada país y genere una nueva serie con la resta entre el cambio porcentual del país $i$ en el año $t$, y el promedio del cambio porcentual del país $i$. En otras palabras, genere una serie con _**desvíos del cambio porcentual promedio**_ $\forall i,t$:
#
# $$Nueva Serie_i = \Delta \% TotalCO2_{i,t} - \mathbb{E}[{\Delta \% TotalCO2_{i,t}}]$$
#
# Luego, para los siguientes países:
#
# - Reino Unido
# - Canadá
# - Alemania
# - Francia
# - Estados Unidos
# - Japón
# - Italia
# - España
#
#
# grafique en un panel _1x2_ la desviación del cambio porcentual respecto al promedio entre 2007 y 2010 en lado izquierdo, y entre 2017 y 2020 en el lado derecho (Hint: Hay comandos que facilitan esta labor. Puede intentar con `fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)`, por ejemplo).
#
# ¿Existe algún país en particular que mostró mayores desviaciones atípicas de emisión de CO2 durante el periodo de la crisis sub-prime? ¿Cómo es el comportamiento de las desviaciones atípicas de CO2 de este país durante la crisis del Covid-19?

# %%
# Calcular el promedio de los cambios porcentuales por país
promedio_cambio_pct = df_co2.groupby('Country')['cambio (%)'].mean()

# Crear una nueva columna que asigne el promedio de cambios a cada país
df_co2['promedio_cambio_pct'] = df_co2['Country'].map(promedio_cambio_pct)
df_co2["Desvios de cambio (%) promedio"] = df_co2["cambio (%)"]- df_co2["promedio_cambio_pct"]
df_co2
# Filtrar los datos para los períodos de interés
df_2007_2010 = df_co2[(df_co2['Country'].isin(paises_seleccionados)) & (df_co2['Year'] >= 2007) & (df_co2['Year'] <= 2010)]
df_2017_2020 = df_co2[(df_co2['Country'].isin(paises_seleccionados))& (df_co2['Year'] >= 2017) & (df_co2['Year'] <= 2020)]

# Crear la figura y los subgráficos (panel 1x2)
fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)


# Gráfico del cambio porcentual anual entre 2007 y 2010
sns.lineplot(data=df_2007_2010, x='Year', y='cambio (%)', hue='Country', marker='o', ax=axes[0])
axes[0].set_title('Cambio Porcentual Anual (2007-2010)')
axes[0].set_xlabel('Año')
axes[0].set_ylabel('Cambio Porcentual (%)')
axes[0].legend_.remove()
axes[0].grid(True)

# Gráfico del cambio porcentual anual entre 2017 y 2020
sns.lineplot(data=df_2017_2020, x='Year', y='cambio (%)', hue='Country', marker='o', ax=axes[1])
axes[1].set_title('Cambio Porcentual Anual (2017-2020)')
axes[1].set_xlabel('Año')
plt.legend(title='País')
axes[1].grid(True)

# Ajustar el diseño
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
#
# Durante la crisis subprime, podemos ver que la india tuvo mayores desviasiones atípicas que el resto de los países. Para ser precisos, sus desviaciones se desviaron hacia arriba: es decir, la india emitió más co2 durante la crisis subprime, contrario a los demás países.
#
# Si miramos a la India en la crisis del covid, este comportamiento es un poco más en linea con los demás países. Sigue teniendo desviaciones por encima del 0, lo que implica que tuvo un aumento de co2 mayor a la media de sus desviaciones, pero este aumento fue menor que lo que había sido años pasados.
#
# Una explicación puede ser que en 2007, la india no estaba tan integrada internacionalmente en los mercados, y quizás la crísis no fue tan significativa, puesto que dependía principalmente de la demanda interna.
#
# No obstante en 2020, la economía más globalizada, sufrio los efectos de la pandemia al igual que el resto de los países.
#
#
# ---

# %% [markdown]
# ### Pregunta 2.7
#
# Genere un nuevo dataframe llamado `df_final`. Para esto, realice un INNER JOIN entre el dataframe `df_co2` y `df_merged` por "año y país" (debería terminar sólo con valores de 2007 si usted realiza un INNER JOIN).
#
# Finalmente, grafique un mapa de calor de correlaciones (_heatmapt_) entre las variables numéricas ,excluyendo fechas.
#
# ¿Qué variables económicas, demográficas y de desarrollo humano muestran relación más importante con las emisiones de CO2? Interprete estas relaciones.

# %%
df_2007 = df_co2[df_co2['Year'] == 2007].copy()
df_final = pd.merge(df_merged, df_2007, on=["Country"], how="inner")
df_final= df_final.drop("Year", axis=1)
df_final= df_final.drop("date", axis=1)

corr_matrix= df_final[df_final.dtypes[df_final.dtypes != "object"].index].corr()

# Crear el heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Personalizar el título
plt.title("Mapa de Calor de Correlaciones")
plt.show()

# %% [markdown]
# ---
#
#
# Las correlaciones más altas que se generan con las emisiones de CO2 son: Population, Area, GDP (bruto y per capita) y los diversos fuels, phones per 1000.
#
# Primero, population y area son variables obviamente relevantes en las emisiones de CO2. Esto, porque como las emisiones son medidas a niveles brutos, claramente países más grandes tendrán mayor consumo de energía, transporte, diversos productos y servicios, etc. Además, son agentes más importantes en los mercados mundiales, por lo que no es sorprendente que tengan grandes industrias muy dependientes de combustibles contaminantes.
#
# Luego, la relación que hay entre el GDP bruto y per capita es positiva. Esto se explica porque países más ricos tienen mayor actividad económica, tipicamente dependiende de la energía y los combustibles fósiles. Otra explicación es que países con más riqueza tienen mayor capacidad de compra y por ende la demanda es mucho más grande, por lo que cada persona está contaminando más al tener mayor consumo. Lo mismo puede aplicarse a la variable de phones per 1000, que es un claro signo de paises ricos. Por ende, países con más teléfonos per capita, contaminan más al estar correlacionados con altos niveles de consumo.
#
# Finalmente, la relación entre emisiones de CO2 y el uso de diversos combustibles es obvia: los combustibles contaminan. Por eso, economías que dependen mucho de cualquier combustible van a tener altos niveles de contaminación.
#
#
#
# ---
